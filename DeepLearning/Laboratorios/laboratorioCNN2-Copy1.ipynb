# %% [markdown]
# # Clasificación de imágenes conjunto de datos Fashion MNIST
# ## Actividad Práctica
#
# En esta sección se empleará el conjunto de datos Fashion MNIST, una colección de imágenes que representa prendas de vestir, calzado y accesorios en el mundo de la moda. Fashion MNIST es ampliamente reconocido en el campo del aprendizaje automático y la visión por computadora como una alternativa al conjunto de datos Digits MNIST. Al igual que Digits MNIST, el conjunto de datos Fashion MNIST consta de 70.000 imágenes en blanco y negro. De estas, 60.000 están destinadas al entrenamiento de modelos, mientras que las 10.000 restantes se reservan para pruebas y evaluación de rendimiento. Cada imagen tiene una dimensión de 28 x 28 píxeles y se representa en un solo canal de color.
#
# En este laboratorio, se utilizará el conjunto de datos Fashion MNIST con el objetivo de diseñar y entrenar un modelo neuronal convolucional (CNN) para alcanzar una precisión de clasificación superior al 90% en el conjunto de prueba. Te proporcionaremos una función que crea la arquitectura inicial del modelo CNN y una plantilla de compilación. Tu tarea es ajustar esta arquitectura y la configuración de compilación de acuerdo con tus conocimientos. Tienes total libertad para agregar, eliminar o ajustar elementos en la arquitectura y cambiar los hiperparámetros según sea necesario. Además puedes usar las funciones de validación y visualización de resultados para observar el desempeño de tu modelo. Cuando consideres que tu modelo ha superado el umbral del 90% de precisión, podrás enviarlo para su evaluación interna.

# %%
# Celda con la importación de librerias

import tensorflow as tf         # Importar TensorFlow
from tensorflow import keras    # Importar la APItensorflow.keras de TensorFlow

import numpy as np              # Librería para trabajar don datos matriciales

import matplotlib.pyplot as plt # Librería para gráficas y visualización

# Inicialización de semillas 
tf.random.set_seed(42)
np.random.seed(42)

# %%
# Conjunto de datos Fashion MNIST
from tensorflow.keras.datasets import fashion_mnist

# %%
# Librería para codificar etiquetas en one-hot
from tensorflow.keras.utils import to_categorical

# %%
def load_data(mnist):
    """
    Esta función carga al entorno de trabajo los datos de entrenamiento, y prueba. Con sus
    etiquetas codificadas con one-hot.
    Parámetros de entrada:
    mnist = Clase detensorflow.keras.datsets con el conjunto de datos fashion mnist
    Parámetros de salida:
    X_train = Conjunto de datos para entrenamiento
    X_test = Conjunto de datos para prueba
    y_train_onehot = Etiquetas del conjunto de entrenamiento codificadas en one-hot
    y_test_onehot = Etiquetas del conjunto de prueba codificadas en one-hot
    y_train = Etiqueta original del conjunto de entrenamiento
    y_test = Etiqueta original del conjunto de prueba
    """

    # Establecer el conjunto de entrenamiento y el conjunto de prueba con sus respectivas
    # etiquetas
    (X_train, y_train), (X_test, y_test) = mnist.load_data()

    # Normalización de los valores de los pixeles de las imágenes
    X_train, X_test = X_train / 255.0, X_test / 255.0

    # Codificación One-Hot para las etiquetas
    y_train_onehot = to_categorical(y_train)
    y_test_onehot =  to_categorical(y_test)

    print(f'Conjunto de datos cargados')
    print(f'Tamaño imágenes de entrenamiento {X_train.shape}')
    print(f'Tamaño imágenes de test {X_test.shape}')
    print(f'Datos por cada etiqueta en X train {np.bincount(y_train)}')

    return X_train.reshape((60000, 28, 28, 1)), X_test.reshape((10000, 28, 28, 1)), y_train_onehot, y_test_onehot, y_train, y_test
### END READ ONLY

# %%
X_train, X_test, y_train_onehot, y_test_onehot, y_train, y_test = load_data(fashion_mnist)
# Out:
# Conjunto de datos cargados
# Tamaño imágenes de entrenamiento (60000, 28, 28)
# Tamaño imágenes de test (10000, 28, 28)
# Datos por cada etiqueta en X train [6000 6000 6000 6000 6000 6000 6000 6000 6000 6000]

# %%
def visualize_instances(X_data, y_data):
    """
    Esta función visualiza una instancia de cada categoria del conjunto mnist
    Parámetros de entrada:
    X_data = Instancias
    y_data = Etiquetas
    Parámetros de salida:
    Grafica con la visualización de la imagen por cada isntancia.
    """
    fig, ax = plt.subplots(nrows=2, ncols=5, sharex=True, sharey=True, figsize=(10, 5))
    ax = ax.flatten()
    for i in range(10):
        img = X_data[y_data == i][0].reshape((28, 28))
        ax[i].imshow(img, cmap='gist_yarg')
        ax[0].set_xticks([])
        ax[0].set_yticks([])
    return plt.show()

# %%
visualize_instances(X_train, y_train)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten

def load_model():
    """
    Esta función construye un modelo neuronal convolucional para el problema de clasificación
    con Fashion MNIST.

    Modifica esta función a tu gusto.

    Salida:
    model = modelo neuronal convolucional entensorflow.keras
    """

    # Inicio del modelo con el nombre pasado por parámetro
    model = Sequential()

    # Capa de entrada dimensiones consistentes con las dimensiones de las imágenes de MNIST
    model.add(Input(shape=(28, 28, 1), name = 'Entrada'))

    # Modifica las capas como consideres necesario 
    
    # Ingresa tu código aqui

    # Primera capa convolucinal Kernel de 3x3 y 2 filtros
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same',name='PrimeraConv2D'))
    # Capa de MaxPooling
    model.add(MaxPooling2D(pool_size=(2, 2),name='PrimeraMaxPooling2D'))
    
    model.add(Conv2D(64,(3, 3), activation='relu', padding='same',name='SegundaConv2D'))
    model.add(MaxPooling2D(pool_size=(2, 2),name='SegundaMaxPooling2D'))
    # Capa de aplanamiento
    model.add(Flatten(name='Aplanado'))
    
    #Capa final densa antes de la salida
    model.add(Dense(150,activation='relu',name='CapaFinalDensa'))
    # Capa de salida con 10 categorías
    model.add(Dense(10, activation='softmax', name = 'Output'))

    return model

# %%
from tensorflow.keras.utils import plot_model
model = load_model()
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=False)

# %%
# Compilar y entrenar el modelo

# También puedes modificar esta celda, cambiando parámetros de la compilación o del
# entrenamiento.

model = load_model()
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
resultsFit = model.fit(X_train, y_train_onehot,
                    epochs=10, 
                    batch_size = 32,
                    validation_data=(X_test, y_test_onehot))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 79s 1ms/sample - loss: 0.3927 - accuracy: 0.8586 - val_loss: 0.3238 - val_accuracy: 0.8839- loss: 1.0517 - accura - ETA: 1:20 - loss: 0.9973  - ETA: 1:18 - loss: 0.914 - ETA: 1:15 - loss: 0.857 - ETA: 1:14 - loss: 0.8145 - accuracy: 0. - ETA: 1:13 - loss: 0.8059 - accura - ETA: 1:13 - los - ETA: 1:10 - loss: 0.7284 - accuracy - ETA: 1:10 - loss: 0.7179 - accuracy - ETA: 1:09 - loss: 0.7067 - accuracy - ETA: 1:09 - loss: 0.6986 - accuracy: 0. - ETA: 1:08 - ETA: 1:06 - loss: 0.6638 - accura - ETA: 1:05 - loss: 0.6557 -  - ETA: 1:04 - loss: 0.6478 - accuracy - ETA: 1: - ETA: 1:02 - loss: 0.6157 - accuracy - ETA: 1:01 - loss: 0.6099 -  - ETA: 1:00 - loss - ETA: 58s - loss: 0.5 - - ETA: 51s - loss: 0.5360 - accuracy: 0 - ETA: 50s - loss: 0.5338 - accurac - ETA: 50s - loss: 0.5274 - accuracy: 0.80 - ETA: 49s - loss: 0.5 - ETA: 47s - loss: 0.5140 - a - ETA: 45s - loss: 0.5060 - ac - ETA: 44s - loss: 0.4999 - a - ETA: 42s - loss: 0.4913 - accurac - ETA: 41s - loss: 0.4871 - accur - ETA: 40s - loss: 0.4843 - accuracy:  - ETA: 40s - loss: 0.4822 - accuracy: 0.82 - ETA: 40s - loss: 0.4820 - accuracy: - ETA: 39s - loss: 0.4800 - accuracy - ETA: 38s - loss: 0.4772 - accur - ETA: 37s - loss: 0.4732 - accu - ETA: 36s - loss: 0.4689 - accur - ETA: 35s - loss: 0.4649 - accuracy: 0.83 - ETA: 34s - loss: 0.4642 - accuracy: 0.8 - ETA: 34s - loss: 0.4636 - accurac - ETA: 33s - loss: - ETA: 31s - loss: 0.4529 - a - ETA: 29s - loss: 0.4 - ETA: 27s - loss: 0.4441 - accuracy: 0.840 - ETA: 27s - loss: 0.4437 - accuracy: 0. - ETA: 26s - loss: 0.4427 - accuracy: 0.8 - ETA: 26s - loss: 0.4418 - a - ETA: 24s - loss - ETA: 22s - loss: 0.4323 - accurac - ETA: 21s - loss: 0. - ETA: 18s - loss: 0.4257 - accura - ETA: 17s - loss: 0.4232 - accuracy:  - ETA: 17s - loss: 0.4221 - accuracy: 0 - ETA: 16s - loss: 0.4208 - accur - ETA: 15s - loss: 0.4184 - accuracy - ETA: 14s - loss: 0.4163 - accurac - ETA: 13s - loss: 0.4141 - a - ETA: 12s - los - ETA: 7s - loss: 0.401 - ETA: 6s - loss: - ETA: 2s - loss: 0.3955 - ac - ETA: 2s - loss: 0.394 - ETA: 1s - loss: 0.3940 - accu - ETA: 0s - loss: 0.3935 - accuracy: 0.85 - ETA: 0s - loss: 0.3932 - accu
# Epoch 2/10
# 60000/60000 [==============================] - 78s 1ms/sample - loss: 0.2545 - accuracy: 0.9070 - val_loss: 0.2744 - val_accuracy: 0.9017 1: - ETA: 1:13 - loss: 0 - ETA: 1:10 - loss: 0.2776 - accu - ETA: 1:09 - loss: 0.271 - ETA: 1:05 - loss: 0.264 - ETA: 1:04 - loss: - ETA: 1:00 - loss: 0.2689 - ac - ETA: 58s - loss: 0.2708 - accur - ETA: 57s - loss: 0.2718 - accuracy: 0.90 - ETA: 57s - loss: 0.2723 - accurac - ETA: 56s - loss:  - ETA: 49s - loss: 0.2718  - ETA: 47s - loss: 0.2701 - accuracy: - ETA: 46s - los - ETA: 43s - loss: 0.2711 -  - ETA: 42s - ETA: 39s - loss: 0.2683 - accuracy: 0 - ETA: 38s - loss: 0.2690 - accuracy:  - ETA: 37s - loss: 0.2693 - accura - ETA: 36s - loss: 0.2674 - ETA: 35s - loss: 0.2675 - accuracy: 0.90 - ETA: 34s - loss: 0.2671 - accuracy: 0 - ETA: 34s - loss: 0.2673 - accuracy: 0.9 - ETA: 34s - loss: 0.2671 - accur - ETA: 32s - loss: 0.2668 - accur - ETA: 31s - loss: 0.2657 - accuracy: 0.903 - ETA: 31s - loss: 0.2 - ETA: 29s - loss: 0.2647 - accur - ETA: 28s - loss: 0.2637 - accuracy: 0.9 - ETA: 28s - loss: 0.2635 - accuracy: 0.90 - ETA: 27s - loss: 0.2630 - accuracy: 0.90 - ETA: 27s - loss: 0.2631 - accuracy: 0.903 - ETA: 27s - loss: 0.2631 - accuracy - ETA: 26s - loss: 0.2630 - accuracy: 0.9 - ETA: 26s - l - E - ETA: 19s - loss: 0.2596 - accuracy: 0.9 - ETA: 18s -  - ETA: 15s - loss: 0.2575 - accuracy: 0.90 - ETA: 15s - loss: 0.2574 - accuracy:  - ETA: 14s - loss: 0.2 - ETA: 12s - loss: 0.2559 - accuracy: 0 - ETA: 12s - loss: 0.2558 - accuracy: 0 - ETA: 11s - loss: 0.2556 - ac - ETA: 10s - ETA: 6s - loss: 0.2557 - accu - ETA: 5s - loss: 0.2556 - accuracy - E - ETA: 3s - loss: 0.2 - ETA: 2s - loss: 0.2 - ETA: 0s - loss: 0.2546 - accuracy - ETA: 0s - loss: 0.2546 - accura
# Epoch 3/10
# 60000/60000 [==============================] - 78s 1ms/sample - loss: 0.2108 - accuracy: 0.9216 - val_loss: 0.2461 - val_accuracy: 0.9092- loss: 0.2251 - accuracy:  - ETA: 1:11 - loss: 0.2237 - accuracy: 0.91 - ETA: 1:11 - loss: 0.2 - ETA: 1:10 - loss: 0.2164  - ETA: 1:09 - loss: 0.2168 - accura - ETA: 1:08 - loss: 0.2170 - accura - ETA: 1:06 - loss: 0.2158 - a - ETA: 57s - loss: 0.2084 - accuracy: 0 - ETA: 57s - loss: 0.2086 - accuracy: 0. - ETA: 56s - loss: 0.2 - ETA: 54s - loss: - ETA: 47s - loss: 0.2090 - accur - ETA: 46s - loss: 0.2094 - accuracy: 0.921 - ETA: 45s - loss: 0.2094 - accur - ETA: 44s - loss: 0.2113 - accura - ETA: 43s - loss: 0.2126 - accuracy: 0.920 - ETA: 43s - loss: 0.21 - ETA: 41s - loss: 0.2121 - accuracy: 0.920 - ETA: - ETA: 37s - loss: 0.2128 - accuracy: 0 - ETA: 37s - loss: 0.2129 - accuracy: - ETA: 36s - loss: 0.2129 - accuracy: 0.920 - ETA: 36s - loss: 0.2129 - accuracy: 0.9 - ETA: 36s - loss: 0.2136 - accura - ETA: 35s - loss: 0.2135 - a  - ETA: 29s - loss: 0.2131 - accuracy: 0 - ETA: 28s - loss: 0.213 - ETA: 26s - loss: 0.2134 - ETA: 24s - loss - ETA: 21s - loss: 0.2119 - accurac - ETA: 21s - loss: 0.2124 - - ETA: 14s - loss: 0.2124 - ETA: 12s - loss: 0.2120 - accur - ETA: 11s - loss: 0.2113 - accur - ETA: 10s - loss: 0.2112 - accu - ETA:  - ETA: 5s - loss: 0.210 - ETA: 4s - l - ETA: 1s - loss: 0.2
# Epoch 4/10
# 60000/60000 [==============================] - 77s 1ms/sample - loss: 0.1780 - accuracy: 0.9338 - val_loss: 0.2441 - val_accuracy: 0.9102loss: 0.1752 - accuracy: 0.93 - ETA: 1:01 - l - ETA: 59s - loss: 0.1747 - accuracy: 0.93 - ETA: 59s - loss: 0.17 - ETA: 57s - loss: 0.1786 - - ETA: 55s - loss: 0.1791 - accu - ETA: 54s - loss: 0.1787 - accuracy: 0.93 - ETA: 53s - loss: 0.1792 - accuracy:  - ETA: 53s - loss: 0.1795 - accuracy: 0.93 - ETA: 53s - loss: 0.1796 - ac - ETA: 51s - loss: 0.1783 - a - ETA: 50s - loss: 0.1780 - a - ETA: 48s - loss: 0.1776 - accuracy: 0. - ETA: 48s - loss: 0.1771 - accuracy: 0.935 - ETA: 48s - loss: 0.1769 - - ETA: 46s - los - ETA: 44s - loss: 0.1752 - accur - ETA: 42s - loss: 0.1744 -  - ETA: 41s - loss: 0.1744 - accuracy: 0.9 - ETA: 41s - loss: 0.1744 - accuracy: 0.936 - ETA: 40s - loss: 0.1742 - accuracy: - ETA: 40s - loss: 0.17 - ETA: 38s - loss: 0.1761 - accurac - ETA: 37s - loss: 0.1761 - accur - ETA: 36s - loss: 0.175 - ETA: 34s - loss: 0.1759 - ac - ETA: 32s - loss - ETA: 30s - loss: 0.1776 - accuracy: 0.9 - ETA: 29s - loss: 0.1775 - - ETA: 28s - loss: 0.1782 - a - ETA: 26s - loss: 0 - ETA: 24s - loss: 0.1771 - - ETA: 22s - loss: 0.1770 -  - ETA: 20s - loss: 0.1773 - accuracy: 0. - ETA: 20s - loss: 0.1776 - accuracy - ETA: 19s - loss: 0.1771 - accuracy: 0.93 - ETA: 19s - loss: 0.1770 - ac - ETA: 18s - loss: 0.1768 - accuracy:  - ETA: 17s - loss: 0.1772 - accur - ETA: 16s - loss: 0.1774 - accuracy: 0.934 - ETA: - ETA: 12s - loss: 0 - ETA: - ETA: 8s - loss: 0.1768 - accuracy: 0.93 - ETA:  - ETA: 6s - loss: - ETA: 4s - loss: 0.1773 -  - ETA: 4s - loss: 0.1771 - accu - ETA: 3s - loss: 0
# Epoch 5/10
# 60000/60000 [==============================] - 77s 1ms/sample - loss: 0.1521 - accuracy: 0.9430 - val_loss: 0.2424 - val_accuracy: 0.9140:06 - loss: 0.1349 - accu - ETA: 1:05 - loss: 0.1349 - accuracy:  - ETA: 1:05 - loss: 0.1358 - accuracy: 0. - ETA: 1:05 - loss: 0.1375 - accuracy - ETA: 1:04 - loss: 0.1383 - accuracy - ETA: 1:04 - loss: 0.1387 - accuracy: 0. - ETA: 1:04 - loss: 0.1398 - accuracy:  - ETA: 1:04 - loss: 0.1397 - ac - ETA: 1:03 - loss: 0.1406 - accura - ETA: 1:02 - loss: 0.1389 - accuracy: 0.94 - ETA: 1:02 - loss: 0 - ETA: 1: - ETA: 59s - loss: 0.1417 - accuracy: 0.948 - ETA: 59s - loss: 0.1418 - accuracy: 0 - ETA: 58s - loss: 0.1424 - accuracy: 0.94 - ETA: 58s - lo - ETA: 55s - loss - ETA: 52s - loss: 0.1426 - accur - ETA: 51s - loss: 0.1438 - accuracy - ETA: 50s - loss: 0.1428 - accuracy: 0.9 - ETA: 50s - loss: 0.1439 - accur - ETA: 49s - loss: 0. - ETA: 47s - loss: 0.1442 - accu - ETA: 46s - loss:  - ETA: 43s - loss: 0.145 - ETA: 41s - loss: 0.1456 - accuracy: 0.946 - ETA: 41s - loss: 0.1453 - accuracy: 0.9 - ETA: 41s - loss: 0.1452 - accuracy: 0 - ETA: 41s - loss: 0.1456 - accu - ETA: 39s - loss: 0.1453  - ETA: 38s - loss: 0. - ETA - ETA: 31s - loss: 0.148 - ETA: 29s - loss: 0.1477 - accuracy: - ETA: 29s - loss: 0.1479 - a - ETA: 27s - loss: 0. - ETA: 25s - loss: 0.1495 - accuracy:  - ETA: 24s - loss: 0.1492 - accuracy: 0.944 - ETA: 24s - - ETA: 21s - loss: 0.1506 - accuracy - ETA: 20s - loss: 0.1504 - accur - ETA: 19s  - ETA: 16s - loss: 0.1506 - accuracy: 0 - ETA: 15s - loss: 0.1508 - accur - ETA: 14s - loss: 0.1510 - accuracy:  - ETA: 14s - loss:  - ETA: 11s - loss: 0.1508 - accuracy - ETA: 10s -
# Epoch 6/10
# 60000/60000 [==============================] - 77s 1ms/sample - loss: 0.1282 - accuracy: 0.9517 - val_loss: 0.2558 - val_accuracy: 0.9177A: 1:12 - loss: 0.1371 - accuracy: 0.95 - ETA: 1:13 - loss: 0.1351 - accuracy: 0. - ETA: 1:13 - loss: 0.1323 - accuracy: 0.95 - ETA: 1:13 - loss: 0.1295 - accuracy: 0.95 - ETA: 1:13 - loss: 0.1 - ETA: 1: - ETA: 1:09 - loss: 0.1328 - accura - ETA: 1:09 - loss: 0.1293 -  - ETA: 1:08 - loss: 0.1306 - accuracy: 0. - ETA: 1:08 - - ETA: 1:06 - loss: 0 - ETA: 1:05 - loss: 0.1279 -  - ETA: 1:04 - loss: 0.1278 -  - ETA: 1:03 - los - ETA: - ETA: 59s - loss: 0.1240 - accuracy: 0.95 - ETA: 59s - loss: 0.1248 - accuracy: 0.9 - ETA: 59s - loss: 0.1245 - accuracy: 0.9 - ETA: 58s - loss: 0.1236 - accuracy: - ETA: 58s - loss: 0.1235 -  - ETA: 56s - loss: 0.1261 - accuracy: - ETA: 55s - loss: 0.1249 - accuracy: 0.955 - ETA: 55s - loss: 0.1246 - accu - ETA: 54s - los - ETA: 51s - loss: 0 - ETA: 4 - ETA: 45s - loss: 0.1249 - accur - ETA: 44s - loss: 0 - ETA: 42s - loss: 0.1256 - accura - ETA: 41s - loss: 0.1256 - ac - ETA: 35s - loss: 0.1265 - accuracy: 0.95 - ETA: 34s - loss: 0.1266 - accuracy:  - E - ETA: 30s - loss: 0.1276 - accuracy: 0.95 - ETA: 30s - loss: 0.1274 - accu - ETA: 28s - loss: 0.1272 - accuracy:  - ETA: 28s - loss: 0.1268 - accuracy: 0.95 - ETA: 28s - loss: 0.1270 - accuracy - ETA: 27s - loss: 0.1272 - accurac - ETA: 26s - loss: 0.1271 - accuracy: 0.95 - ETA: 26s - loss: 0.1269 - - ETA: 24s - loss: 0.1265 - accuracy:  - ETA: 24s - loss: 0.1259 - accura - ETA: 23s - loss: 0.1263 - accuracy - ETA: 22s - loss: 0.1264 - a - ETA: 20s - loss: 0.1266 - accuracy: 0.95 - ETA: 20s - loss: 0.1 - ETA: 18s - loss - ETA: 15s - loss: 0.1266 - accuracy: 0.952 - ETA: 15s - loss: 0.1267  - ETA: 13s - loss: 0.1268 - accur - ETA: 12s - loss: 0.1271 - ETA: 10s - loss: 0.1272 - accu - ETA: 9s - loss: 0.1270 - accuracy - ETA: 9s - loss: 0.1272 - accu - ETA: 8s - loss: 0.1274 - accuracy - E - ETA: 6s - loss: 0.1279  - ETA: 5s - loss: 0.1283  - ETA: 2s - - ETA: 0s - loss: 0.1286 - ac
# Epoch 7/10
# 60000/60000 [==============================] - 77s 1ms/sample - loss: 0.1067 - accuracy: 0.9597 - val_loss: 0.2540 - val_accuracy: 0.91690.1083 - accuracy: 0.95 - ETA: 1:08 - loss: 0.1087 - accu - ETA: 1:07 - loss: 0.1082 -  - ETA: 1:06 - loss: 0.1061 - ac - E - ETA: 1:04 - loss: 0.1028 - accuracy:  - ETA: 1:04 - loss: - ETA: 1:02 - los - ETA: 1:01 - loss: 0.0 - ETA: 1:00 - loss: 0 - ETA: 54s - loss: 0.0966 - accuracy: 0. - ETA: 53s - loss: 0.0965 -  - ETA: 52s - loss: 0.0993 - a - ETA: 51s - los - ETA: 48s - loss: 0.0994 - accuracy: 0.963 - ETA: 48s - loss: 0.0996 -  - ETA: 46s - ETA: 38s - loss: 0.1016 - accuracy: 0.96 - ETA: 38s - loss: 0. - ETA: 36s - loss: 0.1017 - accuracy: 0.962 - ETA: 36s - loss: 0. - ETA: 33s - loss: 0.1023 - accuracy: 0.9 - ETA: 33s - loss: 0.1023 - accuracy: 0.96 - ETA: 3 - ETA: 29s - loss: 0.1035 - accuracy: 0.96 - ETA: 29s - loss: 0.1036 - accur - ETA: 28s - loss: 0.1033 - ac - ETA: 27s - loss: 0.10 - ETA: 25s - loss: 0.1034 - accura - ETA: 24s - loss: 0.1034 - accuracy:  - ETA: 23s - loss: 0.1036 - accuracy:  - ETA: 22s - loss: - ETA: 20s - loss: 0.1029 - accura - ETA: 19s - loss: 0.1029 - - ETA: 17s - loss: 0.1036 - accuracy - ETA - ETA: 6s - loss: 0.1058 - accuracy: 0. - ETA: 6s - loss: 0.1058 - accuracy: 0. - E - ETA: 2s - loss: 0.1061 - accuracy:  - E
# Epoch 8/10
# 60000/60000 [==============================] - 77s 1ms/sample - loss: 0.0889 - accuracy: 0.9665 - val_loss: 0.2866 - val_accuracy: 0.9171 loss: 0.0784 - accuracy: 0 - E - ETA: 53s - loss: 0.0795 - accuracy: 0 - ETA: 53s - loss: 0.0796 - accuracy - ETA: 52s - loss: 0.0810 - accuracy: 0. - ETA: 51s - loss: 0.0810 - accuracy: 0.969 - ETA: 51s - loss: 0.0810 - accuracy: 0.969 - ETA: 51s - loss: 0.0810 - accuracy: 0.96 - ETA: 51s - lo - ETA: 48s - loss: 0.0797 - accuracy: - ETA: 48s - lo - ETA: 45s - loss: 0. - ETA: 42s - loss: 0.0813 - accuracy: - ETA: 42s - loss: 0.0819 - accuracy: 0. - ETA: 41s - loss: - ETA: 39s - loss: 0.0814 -  - ETA: 37s - loss: 0.0815 - a - ETA: 35s - loss: 0.0821 -  - ETA: 34s - loss: 0.0819 - accuracy - ETA: 33s - loss: 0.0827 - accuracy:  - ETA: 32s - loss: 0.0831 - accuracy: 0.9 - ETA: 32s - loss: 0.0832 - acc - ETA: 31s - loss: 0.0839 - ETA: 29s - loss: 0.0844 - accu - ETA: 28s - loss: 0.0848 - accuracy: 0.967 - ETA: 27s - loss: - ETA - ETA: 21s - loss: 0.086 - ETA: 19s - loss: 0.0867 - accuracy: - ETA: 18s - loss: 0.0867 - accuracy: 0.967 - ETA: 18s - loss: 0.0867 - accurac - ETA: 17s - loss: 0.0867 - accuracy: 0 - ETA: 17s - loss: 0.0868 - accuracy: 0. - ETA: 16s - loss: 0.0868 - accuracy: 0 - ETA: 16s - loss: 0.0868 - accuracy: 0. - ETA: 16s - loss: 0.0870 - accuracy - ETA: 15s -  - ETA: 12s - loss: 0.0869 - a - ETA: 10s - l - ETA: 6s - loss: 0.0881 - accuracy: 0. - ETA: 6s - loss: 0.0881 - accu - ETA: 1s - loss: 0.0887 - accuracy:  - ETA: 1s - loss: 0.0888 -  - ETA: 0s - loss: 0.0890 - accuracy:
# Epoch 9/10
# 60000/60000 [==============================] - 76s 1ms/sample - loss: 0.0759 - accuracy: 0.9717 - val_loss: 0.3248 - val_accuracy: 0.91519  - ET - ETA: 30s - loss: 0.0715 - accuracy: 0 - ETA: 29s - loss: 0.0713 - accuracy: 0.9 - ETA: 29s - loss: 0.0719 - accuracy: 0.97 - ETA: 29s - loss: 0.0719 - ac - ETA: 27s - loss: 0.0733 - ac - ETA: 26s - loss: 0.0 - ETA: 24s - loss: 0.0735 - accuracy: - ETA: 23s - loss: 0.0735 - accuracy: 0 - ETA: 22s - loss: 0.0736 - accura - ETA: 21s  - ETA: 18s - loss: 0.0738 -  - ETA:  - ETA: 4s - ETA: 0s - loss: 0.075
# Epoch 10/10
# 60000/60000 [==============================] - 76s 1ms/sample - loss: 0.0621 - accuracy: 0.9775 - val_loss: 0.3301 - val_accuracy: 0.91817s - loss: 0.0552 - accuracy: 0 - ETA: 56s - loss: 0.0544 - accuracy: - ETA: 47s - loss: 0.0573 - ETA: 45s - loss: - ETA:  - ETA: 38s - loss: 0.0568 - accuracy: 0. - ETA: 38s - loss: 0.0568 - accuracy: 0.9 - ETA: 38s - loss: 0.0567 - accura - ETA: 37s - loss: 0.0 - ETA: 35s - loss: 0.05 - ETA: 32s - loss: 0.0572 - accuracy: 0.979 - ETA: 32s - loss: 0.0572 - accuracy: 0.979 - ETA: 32s - loss: 0.0572 - accuracy: 0. - ETA: 32s - loss: 0.0571 - accuracy - ETA: 31s - loss: 0.0574 - accurac - ETA: 30s - loss: 0.0572 - accuracy:  - ETA - ETA: 26s - loss: 0.0581 - accurac - ETA: 25s - loss: 0.0584 - accuracy: 0 - ETA: 24s - loss: 0.0585 - accuracy: 0. - ETA: 24s - loss: 0.0583 - accuracy: 0. - ETA: 23s - loss: 0.0585  - ETA: 2 - ETA: 18s - loss: 0.0602 - accur - ETA: 17s - loss: 0. - ETA: 15s - loss: 0.0606 - a - ETA: 13s - loss: 0.0607 - acc

# %%
def visualization_history(resultsFit):
    """
    Esta función grafica las curvas de precisión a lo largo de las épocas de entrenamiento
    para el conjunto de prueba como el de validación.
    Parámetros:
    resultsFit = historial de entrenamiento de un modelo entensorflow.keras
    Salida:
    Gráfica de la precisión en validación y prueba.
    """
    # Llamado al entrono de la gráfica y fijar tamaño de visualización
    fig, axes = plt.subplots(1, 2, figsize=(13, 5))

    # Graficar la presición de la historia en entrenamiento
    axes[0].plot(range(len(resultsFit.history['accuracy'])), resultsFit.history['accuracy'],
           '#5a2ff4', linestyle = "-", marker = "o",
           label='Precisión entrenamiento', lw = 3)

    # Graficar la presición de la historia en validación
    axes[0].plot(range(len(resultsFit.history['val_accuracy'])), resultsFit.history['val_accuracy'],  '#60d13e',
           label='Precisión validación', linestyle = '-', marker = 'o', lw = 3)
    
    # Umbral 90% de precisión 
    axes[0].plot(range(len(resultsFit.history['val_accuracy'])), 0.9*np.ones(len(resultsFit.history['val_accuracy'])), 
               'red', lw = 3, label = 'Umbral')
               
    # Títulos de los ejes
    axes[0].set_xlabel('Época',fontsize=16)
    axes[0].set_ylabel(r'Precisión',fontsize=16)
    axes[0].set_ylim(top=1) # Límite de la grafica
    axes[0].grid()      # Activar la cuadricula
    axes[0].legend(fontsize=14,loc = 'lower right')   # Establecer la legenda


    # Graficar la pérdida de la historia en entrenamiento
    axes[1].plot(range(len(resultsFit.history['loss'])), resultsFit.history['loss'],
           '#5a2ff4', linestyle = "-", marker = "o",
           label='Pérdida entrenamiento', lw = 3)

    # Graficar la presición de la historia en validación
    axes[1].plot(range(len(resultsFit.history['val_loss'])), resultsFit.history['val_loss'],  '#60d13e',
           label='Pérdida validación', linestyle = '-', marker = 'o', lw = 3)

    # Títulos de los ejes
    axes[1].set_xlabel('Época',fontsize=16)
    axes[1].set_ylabel(r'Pérdida',fontsize=16)
    axes[1].grid()      # Activar la cuadricula
    axes[1].legend(fontsize=14,loc = 'upper right')   # Establecer la legenda


    plt.tight_layout() # Ajusta automáticamente el diseño de la figura
    plt.show()

# %%
# Llamado a la función de visualización de las métricas de la historia del entrenamiento
# del modelo, en la prrimera gráfica se presenta la precisión y en la segunda la pérdida
visualization_history(resultsFit)

# %% [markdown]
# **Verifica que tu modelo supere el umbral de precisión del 90%, para esto las curvas de precisión en el conjunto de prueba, (curva de color verde) debe situarse por encima de la linea de color rojo.** Cuando estes listo selecciona el botón **Enviar tarea**, al enviar tu laboratorio se calificará automáticamente.
#
# **Ayuda:** Puedes intentar cambiando el optimizador a la clase **adam**, modificar en la arquitectura base de 2 filtros a 16 en la primera capa convolucional y agregar otra capa convolucional de 32 filtros. Probando esta configuración de seguro se supera el umbral
